# %% [markdown]
# ## CROP RECOMMENDATION SYSTEM

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/data.csv')

# %%
df
# Out:
#        Unnamed: 0    N   P   K  temperature   humidity        ph    rainfall  \
# 0               0   90  42  43    20.879744  82.002744  6.502985  202.935536
# 1               1   85  58  41    21.770462  80.319644  7.038096  226.655537
# 2               2   60  55  44    23.004459  82.320763  7.840207  263.964248
# 3               3   74  35  40    26.491096  80.158363  6.980401  242.864034
# 4               4   78  42  42    20.130175  81.604873  7.628473  262.717340
# ...           ...  ...  ..  ..          ...        ...       ...         ...
# 26395       26395  107  34  32    26.774637  66.413269  6.780064  177.774507
# 26396       26396   99  15  27    27.417112  56.636362  6.086922  127.924610
# 26397       26397  118  33  30    24.131797  67.225123  6.362608  173.322839
# 26398       26398  117  32  34    26.272418  52.127394  6.758793  127.175293
# 26399       26399  104  18  30    23.603016  60.396475  6.779833  140.937041
#
#        soil_type   label
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26400 entries, 0 to 26399
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   26400 non-null  int64
#  1   N            26400 non-null  int64
#  2   P            26400 non-null  int64
#  3   K            26400 non-null  int64
#  4   temperature  26400 non-null  float64
#  5   humidity     26400 non-null  float64
#  6   ph           26400 non-null  float64
#  7   rainfall     26400 non-null  float64
#  8   soil_type    26400 non-null  int64
#  9   label        26400 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#         Unnamed: 0             N             P             K   temperature  \
# count  26400.00000  26400.000000  26400.000000  26400.000000  26400.000000
# mean   13199.50000     50.551818     53.362727     48.149091     25.616244
# std     7621.16789     36.909642     32.979010     50.637377      5.062694
# min        0.00000      0.000000      5.000000      5.000000      8.825675
# 25%     6599.75000     21.000000     28.000000     20.000000     22.769375
# 50%    13199.50000     37.000000     51.000000     32.000000     25.598693
# 75%    19799.25000     84.250000     68.000000     49.000000     28.561654
# max    26399.00000    140.000000    145.000000    205.000000     43.675493
#
#            humidity            ph      rainfall     soil_type
# count  26400.000000  26400.000000  26400.000000  26400.000000
# mean      71.481779      6.469480    103.463655      1.520455
# std       22.259173      0.773776     54.946937      0.607944
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'N', 'P', 'K', 'temperature', 'humidity', 'ph',
#        'rainfall', 'soil_type', 'label'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'N', 'P', 'K', 'temperature', 'humidity', 'ph',
#        'rainfall', 'soil_type', 'label'],
#       dtype='object')

# %%
df
# Out:
#        Unnamed: 0    N   P   K  temperature   humidity        ph    rainfall  \
# 0               0   90  42  43    20.879744  82.002744  6.502985  202.935536
# 1               1   85  58  41    21.770462  80.319644  7.038096  226.655537
# 2               2   60  55  44    23.004459  82.320763  7.840207  263.964248
# 3               3   74  35  40    26.491096  80.158363  6.980401  242.864034
# 4               4   78  42  42    20.130175  81.604873  7.628473  262.717340
# ...           ...  ...  ..  ..          ...        ...       ...         ...
# 26395       26395  107  34  32    26.774637  66.413269  6.780064  177.774507
# 26396       26396   99  15  27    27.417112  56.636362  6.086922  127.924610
# 26397       26397  118  33  30    24.131797  67.225123  6.362608  173.322839
# 26398       26398  117  32  34    26.272418  52.127394  6.758793  127.175293
# 26399       26399  104  18  30    23.603016  60.396475  6.779833  140.937041
#
#        soil_type   label
# ...

# %%
df.size
# Out:
# 264000

# %%
df.shape
# Out:
# (26400, 10)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'N', 'P', 'K', 'temperature', 'humidity', 'ph',
#        'rainfall', 'soil_type', 'label'],
#       dtype='object')

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# soil_type        int64
# label           object
# dtype: object

# %%
df['label'].value_counts()
# Out:
# label
# rice           1200
# maize          1200
# jute           1200
# cotton         1200
# coconut        1200
# papaya         1200
# orange         1200
# apple          1200
# muskmelon      1200
# watermelon     1200
# grapes         1200
# mango          1200
# banana         1200
# pomegranate    1200
# lentil         1200
# blackgram      1200
# mungbean       1200
# mothbeans      1200
# pigeonpeas     1200
# kidneybeans    1200
# chickpea       1200
# coffee         1200
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

soil_type_encoder = LabelEncoder()
label_encoder = LabelEncoder()

df['soil_type'] = soil_type_encoder.fit_transform(df['soil_type'])

df['label'] = label_encoder.fit_transform(df['label'])

df.head()
# Out:
#    Unnamed: 0   N   P   K  temperature   humidity        ph    rainfall  \
# 0           0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1           1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2           2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3           3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4           4  78  42  42    20.130175  81.604873  7.628473  262.717340
#
#    soil_type  label
# 0          2     20
# 1          2     20
# 2          2     20
# 3          2     20
# 4          2     20

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split


X = df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'soil_type']].values
y = df['label'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
# !pip install torch torchvision torchaudio torch-geometric

# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from sklearn.preprocessing import LabelEncoder
import torch.optim as optim

# Load your dataset (assuming df is your DataFrame)
# Convert categorical 'soil_type' to numeric using LabelEncoder
soil_type_encoded = LabelEncoder().fit_transform(df['soil_type'])

# Extract features and convert to tensors
X = df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']].values
X = torch.tensor(X, dtype=torch.float)
soil_type_encoded = torch.tensor(soil_type_encoded, dtype=torch.float).view(-1, 1)

# Combine soil_type with other features
X = torch.cat([X, soil_type_encoded], dim=1)
y = torch.tensor(df['label'].values, dtype=torch.long)

# Number of classes
num_classes = len(torch.unique(y))
print(f'Number of classes: {num_classes}')

# Create a dummy edge_index for the graph (this should be adapted to your specific problem)
edge_index = torch.tensor([[0, 1], [1, 0]], dtype=torch.long)

# Create PyG Data object
data = Data(x=X, edge_index=edge_index, y=y)

# Define the GNN model
class GNN(torch.nn.Module):
    def __init__(self):
        super(GNN, self).__init__()
        self.conv1 = GCNConv(X.shape[1], 16)  # First GCN layer
        self.conv2 = GCNConv(16, num_classes)  # Output layer adjusted to num_classes

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)

# Initialize the model, optimizer, and loss function
model = GNN()
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

# Training loop
model.train()
for epoch in range(200):  # Adjust the number of epochs as needed
    optimizer.zero_grad()  # Reset the gradients to zero
    out = model(data)  # Forward pass
    loss = criterion(out, data.y)  # Calculate loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update model parameters
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Model evaluation (for illustration, typically you'd split your data into train/test)
model.eval()
_, pred = model(data).max(dim=1)
correct = pred.eq(data.y).sum().item()
accuracy = correct / data.num_nodes
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Number of classes: 22
# Epoch 1, Loss: 43.864402770996094
# Epoch 2, Loss: 36.8744010925293
# Epoch 3, Loss: 31.070453643798828
# Epoch 4, Loss: 26.082366943359375
# Epoch 5, Loss: 22.00369644165039
# Epoch 6, Loss: 18.903989791870117
# Epoch 7, Loss: 16.414316177368164
# Epoch 8, Loss: 14.175745964050293
# Epoch 9, Loss: 12.10631275177002
# Epoch 10, Loss: 10.311782836914062
# Epoch 11, Loss: 8.968390464782715
# Epoch 12, Loss: 7.90927267074585
# Epoch 13, Loss: 7.02126932144165
# Epoch 14, Loss: 6.243815898895264
# Epoch 15, Loss: 5.52115535736084
# Epoch 16, Loss: 4.864455699920654
# Epoch 17, Loss: 4.340968608856201
# Epoch 18, Loss: 3.9499030113220215
# Epoch 19, Loss: 3.633209228515625
# Epoch 20, Loss: 3.352325916290283
# Epoch 21, Loss: 3.121526002883911
# Epoch 22, Loss: 2.9546525478363037
# Epoch 23, Loss: 2.8454349040985107
# Epoch 24, Loss: 2.773167133331299
# Epoch 25, Loss: 2.7164721488952637
# Epoch 26, Loss: 2.6623997688293457
# Epoch 27, Loss: 2.606564521789551
# ...

# %%
import torch
from torch_geometric.data import Data

def safe_transform(label_encoder, value, default=-1):
    try:
        return label_encoder.transform([value])[0]
    except ValueError:
        return default  # or handle it in another appropriate way

# New sample
new_sample = {
    'N': 74,
    'P': 35,
    'K': 40,
    'temperature': 26.11,
    'humidity': 80.12,
    'ph': 6.9,
    'rainfall': 242.8,
    'soil_type': 'clay'  # Example categorical input
}

# Encode the soil_type using the saved LabelEncoder
new_soil_type_encoded = safe_transform(soil_type_encoder, new_sample['soil_type'])
new_soil_type_encoded = torch.tensor([new_soil_type_encoded], dtype=torch.float).view(-1, 1)

# Prepare the input features tensor
new_input = torch.tensor([[new_sample['N'], new_sample['P'], new_sample['K'],
                           new_sample['temperature'], new_sample['humidity'],
                           new_sample['ph'], new_sample['rainfall']]], dtype=torch.float)

# Combine the encoded soil_type with other features
new_input = torch.cat([new_input, new_soil_type_encoded], dim=1)

# Create a dummy edge_index for the single input (since GNN expects edge information)
edge_index = torch.tensor([[0], [0]], dtype=torch.long)  # Self-loop edge for single node

# Create a PyG Data object for the new input
new_data = Data(x=new_input, edge_index=edge_index)

# Put the model in evaluation mode and predict
model.eval()
with torch.no_grad():
    output = model(new_data)  # Get the model output
    _, predicted_class = output.max(dim=1)  # Get the class with the highest probability

# Decode the predicted class to its corresponding label name
predicted_label_name = label_encoder.inverse_transform([predicted_class.item()])

# Print the predicted class label name
print(f'Predicted class label: {predicted_label_name[0]}')
# Out:
# Predicted class label: rice
